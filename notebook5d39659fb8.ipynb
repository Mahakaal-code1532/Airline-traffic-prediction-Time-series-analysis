# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;color:white;">Table of Contents</p>
# </div>
#
# <div align="center">
# <img src="https://365datascience.com/resources/blog/2019-11-what-is-time-series-data-compressed-1024x576.jpg" width=500/>
# </div>
#
# 1. [**Intial Setup**](#section-one)
#     1. [**Import Standard Packages**](#section-one_one)
#     2. [**Import Time Series Data : Airline Passenger Traffic**](#section-one_two)
# 2. [**Time Series Analysis**](#section-two)
#     1. [**Plot Time Series Data**](#section-two_one)
#     2. [**Missing Value Treatment**](#section-two_two)
#         1. [**Mean Imputation**](#section-two_two_one)
#         2. [**Linear Interpolation**](#section-two_two_two)
#         3. [**Use Linear Interpolation to Impute Missing Value**](#section-two_two_three)
#     3. [**Outlier Detection**](#section-two_three)
#         1. [**Box Plot & Interquartile Range**](#section-two_three_one)
#         2. [**Histogram Plot**](#section-two_three_two)
#     4. [**Time Series Decomposition**](#section-two_four)
#         1. [**Additive Seasonal Decompostion**](#section-two_four_one)
#         2. [**Multiplicative Seasonal Decomposition**](#section-two_four_two)
# 3. [**Build and Evaluate Time Series Forecast**](#section-three)
#     1. [**Splitting Time Series into Training and Test Series**](#section-three_one)
# 4. [**Simple Time Series Methods**](#section-four)
#     1. [**Naive Method**](#section-four_one)
#         1. [**Plot Train, Test and Forecast**](#section-four_one_one)
#         2. [**Calculate RMSE and MAPE to Evaluate Forecast**](#section-four_one_two)
#     2. [**Simple Average Method**](#section-four_two)
#         1. [**Plot Train, Test and Forecast**](#section-four_two_one)
#         2. [**Calculate RMSE and MAPE to Evaluate Forecast**](#section-four_two_two)
#     3. [**Simple Moving Average Method**](#section-four_three)
#         1. [**Plot Train, Test and Forecast**](#section-four_three_one)
#         2. [**Calculate RMSE and MAPE to Evaluate Forecast**](#section-four_three_two)
# 5. [**Exponential Smoothing Methods**](#section-five)
#     1. [**Simple Exponential Smoothing**](#section-five_one)
#         1. [**Plot Train, Test and Forecast**](#section-five_one_one)
#         2. [**Calculate RMSE and MAPE to Evaluate Forecast**](#section-five_one_two)
#     2. [**Holt's Exponential Smoothing Method with Trend**](#section-five_two)
#         1. [**Plot Train, Test and Forecast**](#section-five_two_one)
#         2. [**Calculate RMSE and MAPE to Evaluate Forecast**](#section-five_two_two)
#     3. [**Holt Winter's Additive Method with Trend & Seasonality**](#section-five_three)
#         1. [**Plot Train, Test and Forecast**](#section-five_three_one)
#         2. [**Calculate RMSE and MAPE to Evaluate Forecast**](#section-five_three_two)
#     4. [**Holt Winter's Multiplicative Method with Trend & Seasonality**](#section-five_four)
#         1. [**Plot Train, Test and Forecast**](#section-five_four_one)
#         2. [**Calculate RMSE and MAPE to Evaluate Forecast**](#section-five_four_two)
# 6. [**Auto Regressive Models**](#section-six)
#     1. [**Stationary vs Non-stationary Time Series**](#section-six_one)
#         1. [**Time Series Plot**](#section-six_one_one)
#         2. [**Augumented Dickey-Fuller (ADF) Test**](#section-six_one_two)
#         3. [**KPSS Test**](#section-six_one_three)
#     2. [**Box Cox Transformation**](#section-six_two)
#     3. [**Differencing**](#section-six_three)
#         1. [**ADF Test**](#section-six_three_one)
#         2. [**KPSS Test**](#section-six_three_two)
#         3. [**Auto-Correlation Function (ACF) Plot**](#section-six_three_three)
#         4. [**Partial Auto-Correlation Function (ACF) Plot**](#section-six_three_four)
#     4. [**Split into Train & Test Datasets**](#section-six_four)
#     5. [**Auto Regression Method (AR)**](#section-six_five)
#         1. [**Recover Original Time Series Forecast**](#section-six_five_one)
#         2. [**Plot Train, Test and Forecast**](#section-six_five_two)
#         3. [**Calculate RMSE and MAPE to Evaluate Forecast**](#section-six_five_three)
#     6. [**Moving Average Method (AR)**](#section-six_six)
#         1. [**Recover Original Time Series Forecast**](#section-six_six_one)
#         2. [**Plot Train, Test and Forecast**](#section-six_six_two)
#         3. [**Calculate RMSE and MAPE to Evaluate Forecast**](#section-six_six_three)
#     7. [**Auto Regressive Moving Average Method (ARMA)**](#section-six_seven)
#         1. [**Recover Original Time Series Forecast**](#section-six_seven_one)
#         2. [**Plot Train, Test and Forecast**](#section-six_seven_two)
#         3. [**Calculate RMSE and MAPE to Evaluate Forecast**](#section-six_seven_three)
#     8. [**Auto Regressive Integrated Moving Average Method (ARIMA)**](#section-six_eight)
#         1. [**Recover Original Time Series Forecast**](#section-six_eight_one)
#         2. [**Plot Train, Test and Forecast**](#section-six_eight_two)
#         3. [**Calculate RMSE and MAPE to Evaluate Forecast**](#section-six_eight_three)
#     9. [**Seasonal Auto Regressive Integrated Moving Average Method (SARIMA)**](#section-six_nine)
#         1. [**Recover Original Time Series Forecast**](#section-six_nine_one)
#         2. [**Plot Train, Test and Forecast**](#section-six_nine_two)
#         3. [**Calculate RMSE and MAPE to Evaluate Forecast**](#section-six_nine_three)
#     10. [**Seasonal Auto Regressive Integrated Moving Average with Exogeneous variable Method (SARIMAX)**](#section-six_ten)
#         1. [**Recover Original Time Series Forecast**](#section-six_ten_one)
#         2. [**Plot Train, Test and Forecast**](#section-six_ten_two)
#         3. [**Calculate RMSE and MAPE to Evaluate Forecast**](#section-six_ten_three)

# %% [markdown]
# <a id="section-one"></a>
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;color:white;">Initial Setup</p>
# </div>
#
# <a id="section-one_one"></a>
# ## Import Standard Packages

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <a id="section-one_two"></a>
# ## Import Time Series Data : Airline Passenger Traffic

# %%
data = pd.read_csv("../input/airline-passenger-traffic/airline-passenger-traffic(1).csv", header=None)
data.columns = ['Month', 'Passengers']
data.Month = pd.to_datetime(data.Month, format='%Y-%m')
data.Passengers = data.Passengers.astype("float64")
data = data.set_index('Month')
data.head(12)

# %% [markdown]
# <a id="section-two"></a>
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;color:white;">Time Series Analysis</p>
# </div>
#
# <a id="section-two_one"></a>
# ## Plot Time Series Data

# %%
data.plot(figsize=(12,4))
plt.legend(loc='best')
plt.title('Airline Passenger Traffic Data')
plt.show(block=False)

# %% [markdown]
# <a id="section-two_two"></a>
# ## Missing Value Treatment
#
# <a id="section-two_two_one"></a>
# ### Mean Imputation

# %%
data['Passengers_Mean_Imputation'] = data.Passengers.fillna(data.Passengers.mean())

plt.figure(figsize=(12,4))
plt.plot(data.Passengers_Mean_Imputation, label='Passengers_Mean_Imputation')
plt.plot(data.Passengers, label='Passengers')
plt.legend(loc='best')
plt.title('Missing Value Treatment: Mean Imputation')
plt.show(block=False)

# %% [markdown]
# <a id="section-two_two_two"></a>
# ### Linear Interpolation

# %%
data['Passengers_Linear_Interpolation'] = data.Passengers.interpolate(method='linear')

plt.figure(figsize=(12,4))
plt.plot(data.Passengers_Linear_Interpolation, label='Passengers_Linear_Interpolation')
plt.plot(data.Passengers, label='Passengers')
plt.legend(loc='best')
plt.title('Missing Value Treatment: Linear Interpolation')
plt.show(block=False)

# %% [markdown]
# <a id="section-two_two_three"></a>
# ### Use Linear Interpolation to Impute Missing Value

# %%
data.Passengers = data.Passengers_Linear_Interpolation
data.drop(columns=['Passengers_Mean_Imputation','Passengers_Linear_Interpolation'],inplace=True)
data.head()

# %% [markdown]
# <a id="section-two_three"></a>
# ## Outlier Detection
#
# <a id="section-two_three_one"></a>
# ### Box Plot & Interquartile Range

# %%
import seaborn as sns

fig = plt.subplots(figsize=(12, 2))
ax = sns.boxplot(x = data.Passengers, whis = 1.5)

# %% [markdown]
# <a id="section-two_three_two"></a>
# ### Histogram Plot

# %%
fig = data.Passengers.hist(figsize=(12,4))

# %% [markdown]
# No outliers detected in this time series data
#
# <a id="section-two_four"></a>
# ## Time Series Decomposition
#
# <a id="section-two_four_one"></a>
# ### Additive Seasonal Decompostion

# %%
from pylab import rcParams
import statsmodels.api as sm

rcParams['figure.figsize'] = 12,8
decomposition = sm.tsa.seasonal_decompose(data.Passengers, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# <a id="section-two_four_two"></a>
# ### Multiplicative Seasonal Decomposition

# %%
decomposition = sm.tsa.seasonal_decompose(data.Passengers, model='multiplicative')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# <a id="section-three"></a>
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;color:white;">Build and Evaluate Time Series Forecast</p>
# </div>
#
# <a id="section-three_one"></a>
# ## Splitting Time Series into Training and Test Series

# %%
train_len = 120
train = data[0:train_len]
test = data[train_len:]

# %% [markdown]
# <a id="section-four"></a>
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;color:white;">Simple Time Series Methods</p>
# </div>
#
# <a id="section-four_one"></a>
# ## Naive Method

# %%
def create_method(title, func):
    y_hat = test.copy()
    y_hat[title] = func
    return y_hat
    
y_hat_naive = create_method('naive_forecast', train.Passengers[train_len - 1])

# %% [markdown]
# <a id="section-four_one_one"></a>
# ### Plot Train, Test and Forecast

# %%
def plot_method(y_hat, title):
    plt.figure(figsize=(12,4))
    plt.plot(train.Passengers, label = 'Train')
    plt.plot(test.Passengers, label = 'Test')
    plt.plot(y_hat, label = title + ' Forecast')
    plt.legend(loc='best')
    plt.title(title + ' Method')
    plt.show()
    
plot_method(y_hat_naive.naive_forecast, 'Naive')

# %% [markdown]
# <a id="section-four_one_two"></a>
# ### Calculate RMSE and MAPE to Evaluate Forecast

# %%
from sklearn.metrics import mean_squared_error

def calculate_error(y_hat, title, prevResults, length):
    rmse = np.sqrt(mean_squared_error(test.Passengers, y_hat[length:])).round(2)
    mape = np.round(np.mean(np.abs(test.Passengers-y_hat[length:])/test.Passengers)*100, 2)

    results = pd.DataFrame({'Method':[title + ' Method'], 'RMSE':[rmse], 'MAPE':[mape]})
    results = pd.concat([prevResults, results])
    return results

results = calculate_error(y_hat_naive.naive_forecast, 'Naive', None, 0)
results

# %% [markdown]
# <a id="section-four_two"></a>
# ## Simple Average Method

# %%
y_hat_avg = create_method('avg_forecast', train.Passengers.mean())

# %% [markdown]
# <a id="section-four_two_one"></a>
# ### Plot Train, Test and Forecast

# %%
plot_method(y_hat_avg.avg_forecast, 'Simple Average')

# %% [markdown]
# <a id="section-four_two_two"></a>
# ### Calculate RMSE and MAPE to Evaluate Forecast

# %%
results = calculate_error(y_hat_avg.avg_forecast, 'Simple Average', results, 0)
results

# %% [markdown]
# <a id="section-four_three"></a>
# ## Simple Moving Average Method

# %%
y_hat_sma = data.copy()
ma_window = 12
y_hat_sma['sma_forecast'] = data.Passengers.rolling(ma_window).mean()
y_hat_sma.sma_forecast[train_len:] = y_hat_sma.sma_forecast[train_len-1]

# %% [markdown]
# <a id="section-four_three_one"></a>
# ### Plot Train, Test and Forecast

# %%
plot_method(y_hat_sma.sma_forecast, 'Simple Moving Average')

# %% [markdown]
# <a id="section-four_three_two"></a>
# ### Calculate RMSE and MAPE to Evaluate Forecast

# %%
results = calculate_error(y_hat_sma.sma_forecast, 'Simple Moving Average', results, train_len)
results

# %% [markdown]
# <a id="section-five"></a>
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;color:white;">Exponential Smoothing Methods</p>
# </div>
#
# <a id="section-five_one"></a>
# ## Simple Exponential Smoothing

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

model = SimpleExpSmoothing(train.Passengers)
model_fit = model.fit(smoothing_level=0.2, optimized=False)
model_fit.params

y_hat_ses = test.copy()
y_hat_ses['ses_forecast'] = model_fit.forecast(24)

# %% [markdown]
# <a id="section-five_one_one"></a>
# ### Plot Train, Test and Forecast

# %%
plot_method(y_hat_ses.ses_forecast, 'Simple Exponential Smoothing')

# %% [markdown]
# <a id="section-five_one_two"></a>
# ### Calculate RMSE and MAPE to Evaluate Forecast

# %%
results = calculate_error(y_hat_ses.ses_forecast, 'Simple Exponential Smoothing', results, 0)
results

# %% [markdown]
# <a id="section-five_two"></a>
# ## Holt's Exponential Smoothing Method with Trend

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

model = ExponentialSmoothing(np.array(train.Passengers), seasonal_periods=12, trend='additive', seasonal=None)
model_fit = model.fit(smoothing_level=0.2, smoothing_slope=0.01, optimized=False)

print(model_fit.params)

y_hat_holt = create_method('holt_forecast', model_fit.forecast(24))

# %% [markdown]
# <a id="section-five_two_one"></a>
# ### Plot Train, Test and Forecast

# %%
plot_method(y_hat_holt.holt_forecast, 'Holt\'s Exponential Smoothing')

# %% [markdown]
# <a id="section-five_two_two"></a>
# ### Calculate RMSE and MAPE to Evaluate Forecast

# %%
results = calculate_error(y_hat_holt.holt_forecast, 'Holt\'s Exponential Smoothing', results, 0)
results

# %% [markdown]
# <a id="section-five_three"></a>
# ## Holt Winter's Additive Method with Trend & Seasonality

# %%
model = ExponentialSmoothing(np.asarray(train.Passengers), seasonal_periods=12, trend='add', seasonal='add')
model_fit = model.fit(optimized=True)

print(model_fit.params)

y_hat_hwa = create_method('hwa_forecast', model_fit.forecast(24))

# %% [markdown]
# <a id="section-five_three_one"></a>
# ### Plot Train, Test and Forecast

# %%
plot_method(y_hat_hwa.hwa_forecast, 'Holt\'s Winter Additive')

# %% [markdown]
# <a id="section-five_three_two"></a>
# ### Calculate RMSE and MAPE to Evaluate Forecast

# %%
results = calculate_error(y_hat_hwa.hwa_forecast, 'Holt\'s Winter Additive', results, 0)
results

# %% [markdown]
# <a id="section-five_four"></a>
# ## Holt Winter's Multiplicative Method with Trend & Seasonality

# %%
final_model = ExponentialSmoothing(np.asarray(train.Passengers), trend='mul',seasonal='mul',seasonal_periods=12)
model_fit = final_model.fit(optimized=True)

print(model_fit.params)

y_hat_hwm = create_method('hwm_forecast', model_fit.forecast(24))

# %% [markdown]
# <a id="section-five_four_one"></a>
# ### Plot Train, Test and Forecast

# %%
plot_method(y_hat_hwm.hwm_forecast, 'Holt\'s Winter Multiplicative')

# %% [markdown]
# <a id="section-five_four_two"></a>
# ### Calculate RMSE and MAPE to Evaluate Forecast

# %%
# results = calculate_error(y_hat_hwm.hwm_forecast, 'Holt\'s Winter Multiplicative', results, 0)
# results

# %% [markdown]
# <a id="section-six"></a>
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;color:white;">Auto Regressive Models</p>
# </div>
#
# <a id="section-six_one"></a>
# ## Stationary vs Non-stationary Time Series
#
# <a id="section-six_one_one"></a>
# ### Time Series Plot

# %%
data.Passengers.plot(figsize=(12,4))
plt.legend(loc='best')
plt.title('Airline Passenger Traffic Data')
plt.show()

# %% [markdown]
# <a id="section-six_one_two"></a>
# ### Augumented Dickey-Fuller (ADF) Test

# %%
from statsmodels.tsa.stattools import adfuller

adf_test = adfuller(data.Passengers)

print('ADF Statistics: %f' % adf_test[0])
print('Critical Value @ 0.05: %.2f' % adf_test[4]['5%'])
print('p-value: %f' % adf_test[1])

# %% [markdown]
# <a id="section-six_one_three"></a>
# ### KPSS Test

# %%
import warnings
warnings.filterwarnings('ignore')

from statsmodels.tsa.stattools import kpss

kpss_test = kpss(data.Passengers)

print('KPSS Statistics: %f' % kpss_test[0])
print('Critical Value @ 0.05: %.2f' % kpss_test[3]['5%'])
print('p-value: %f' % kpss_test[1])

# %% [markdown]
# <a id="section-six_two"></a>
# ## Box Cox Transformation

# %%
from scipy.stats import boxcox

data_boxcox = pd.Series(boxcox(data.Passengers, lmbda=0), index = data.index)

plt.figure(figsize=(12, 4))
plt.plot(data_boxcox, label='After Box Cox Transformation')
plt.legend(loc='best')
plt.title('After Box Cox Transformation')
plt.show()

# %% [markdown]
# <a id="section-six_three"></a>
# ## Differencing

# %%
data_boxcox_diff = pd.Series(data_boxcox - data_boxcox.shift(), index = data.index)
data_boxcox_diff.dropna(inplace=True)

plt.figure(figsize=(12, 4))
plt.plot(data_boxcox_diff, label='After Box Cox Transformation & Differencing')
plt.legend(loc='best')
plt.title('After Box Cox Transformation & Differencing')
plt.show()

# %% [markdown]
# <a id="section-six_three_one"></a>
# ### ADF Test

# %%
adf_test = adfuller(data_boxcox_diff)

print('ADF Statistics: %f' % adf_test[0])
print('Critical Value @ 0.05: %.2f' % adf_test[4]['5%'])
print('p-value: %f' % adf_test[1])

# %% [markdown]
# <a id="section-six_three_two"></a>
# ### KPSS Test

# %%
kpss_test = kpss(data_boxcox_diff)

print('KPSS Statistics: %f' % kpss_test[0])
print('Critical Value @ 0.05: %.2f' % kpss_test[3]['5%'])
print('p-value: %f' % kpss_test[1])

# %% [markdown]
# <a id="section-six_three_three"></a>
# ### Auto-Correlation Function (ACF) Plot

# %%
from statsmodels.graphics.tsaplots import plot_acf

plt.figure(figsize=(12, 4))
plot_acf(data_boxcox_diff, ax=plt.gca(), lags=30)
plt.show()

# %% [markdown]
# <a id="section-six_three_four"></a>
# ### Partial Auto-Correlation Function (PACF) Plot

# %%
from statsmodels.graphics.tsaplots import plot_pacf

plt.figure(figsize=(12, 4))
plot_pacf(data_boxcox_diff, ax=plt.gca(), lags=30)
plt.show()

# %% [markdown]
# <a id="section-six_four"></a>
# ## Split into Train & Test Datasets

# %%
train_data_boxcox = data_boxcox[:train_len]
test_data_boxcox = data_boxcox[train_len:]

train_data_boxcox_diff = data_boxcox_diff[:train_len-1]
test_data_boxcox_diff = data_boxcox_diff[train_len-1:]

# %% [markdown]
# <a id="section-six_five"></a>
# ## Auto Regression Method (AR)

# %%
from statsmodels.tsa.arima_model import ARIMA

model = ARIMA(train_data_boxcox_diff, order=(1,0,0))
model_fit = model.fit()

print(model_fit.params)

# %% [markdown]
# <a id="section-six_five_one"></a>
# ### Recover Original Time Series Forecast

# %%
def recover_orginal_time_series(title):
    y_hat = data_boxcox_diff.copy()
    y_hat[title+'_forecast_boxcox_diff'] = model_fit.predict(data_boxcox_diff.index.min(), data_boxcox_diff.index.max())
    y_hat[title+'_forecast_boxcox'] = y_hat[title+'_forecast_boxcox_diff'].cumsum()
    y_hat[title+'_forecast_boxcox'] = y_hat[title+'_forecast_boxcox'].add(data_boxcox[0])
    y_hat[title+'_forecast'] = np.exp(y_hat[title+'_forecast_boxcox'])
    return y_hat
    
y_hat_ar = recover_orginal_time_series('ar')

# %% [markdown]
# <a id="section-six_five_two"></a>
# ### Plot Train, Test and Forecast

# %%
plot_method(y_hat_ar.ar_forecast[test.index.min():], 'Auto Regression')

# %% [markdown]
# <a id="section-six_five_three"></a>
# ### Calculate RMSE and MAPE to Evaluate Forecast

# %%
results = calculate_error(y_hat_ar.ar_forecast[test.index.min():], 'Auto Regression', results, 0)
results

# %% [markdown]
# <a id="section-six_six"></a>
# ## Moving Average Method (MA)

# %%
model = ARIMA(train_data_boxcox_diff, order=(0,0,1))
model_fit = model.fit()

print(model_fit.params)

# %% [markdown]
# <a id="section-six_six_one"></a>
# ### Recover Original Time Series Forecast

# %%
y_hat_ma = recover_orginal_time_series('ma')

# %% [markdown]
# <a id="section-six_six_two"></a>
# ### Plot Train, Test and Forecast

# %%
plot_method(y_hat_ma.ma_forecast[test.index.min():], 'Moving Average')

# %% [markdown]
# <a id="section-six_six_three"></a>
# ### Calculate RMSE and MAPE to Evaluate Forecast

# %%
results = calculate_error(y_hat_ma.ma_forecast[test.index.min():], 'Moving Average', results, 0)
results

# %% [markdown]
# <a id="section-six_seven"></a>
# ## Auto Regressive Moving Average Method (ARMA)

# %%
model = ARIMA(train_data_boxcox_diff, order=(1,0,1))
model_fit = model.fit()

print(model_fit.params)

# %% [markdown]
# <a id="section-six_seven_one"></a>
# ### Recover Original Time Series Forecast

# %%
y_hat_arma = recover_orginal_time_series('arma')

# %% [markdown]
# <a id="section-six_seven_two"></a>
# ### Plot Train, Test and Forecast

# %%
plot_method(y_hat_arma.arma_forecast[test.index.min():], 'Auto Regressive Moving Average')

# %% [markdown]
# <a id="section-six_seven_three"></a>
# ### Calculate RMSE and MAPE to Evaluate Forecast

# %%
results = calculate_error(y_hat_arma.arma_forecast[test.index.min():], 'Auto Regressive Moving Average', results, 0)
results

# %% [markdown]
# <a id="section-six_eight"></a>
# ## Auto Regressive Integrated Moving Average Method (ARIMA)

# %%
model = ARIMA(train_data_boxcox, order=(1,1,1))
model_fit = model.fit()

print(model_fit.params)

# %% [markdown]
# <a id="section-six_eight_one"></a>
# ### Recover Original Time Series Forecast

# %%
y_hat_arima = recover_orginal_time_series('arima')

# %% [markdown]
# <a id="section-six_eight_two"></a>
# ### Plot Train, Test and Forecast

# %%
plot_method(y_hat_arima.arima_forecast[test.index.min():], 'Auto Regressive Integrated Moving Average')

# %% [markdown]
# <a id="section-six_eight_three"></a>
# ### Calculate RMSE and MAPE to Evaluate Forecast

# %%
results = calculate_error(y_hat_arima.arima_forecast[test.index.min():], 'Auto Regressive Integrated Moving Average', results, 0)
results

# %% [markdown]
# <a id="section-six_nine"></a>
# ## Seasonal Auto Regressive Integrated Moving Average Method (SARIMA)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

model = SARIMAX(train_data_boxcox, order=(1,1,1), seasonal_order=(1,1,1,12))
model_fit = model.fit()

print(model_fit.params)

# %% [markdown]
# <a id="section-six_nine_one"></a>
# ### Recover Original Time Series Forecast

# %%
y_hat_sarima = data_boxcox_diff.copy()
y_hat_sarima['sarima_forecast_boxcox'] = model_fit.predict(data_boxcox_diff.index.min(), data_boxcox_diff.index.max())
y_hat_sarima['sarima_forecast'] = np.exp(y_hat_sarima['sarima_forecast_boxcox'])

# %% [markdown]
# <a id="section-six_nine_two"></a>
# ### Plot Train, Test and Forecast

# %%
plot_method(y_hat_sarima.sarima_forecast[test.index.min():], 'Seasonal Auto Regressive Integrated Moving Average')

# %% [markdown]
# <a id="section-six_nine_three"></a>
# ### Calculate RMSE and MAPE to Evaluate Forecast

# %%
results = calculate_error(y_hat_sarima.sarima_forecast[test.index.min():], 'Seasonal Auto Regressive Integrated Moving Average', results, 0)
results

# %% [markdown]
# <a id="section-six_nine"></a>
# ## Seasonal Auto Regressive Integrated Moving Average with Exogeneous varaible Method (SARIMAX)

# %%
promo = pd.read_csv('../input/promotion/promotion.csv', header=None)

promo.columns = ['Month', 'Event']
promo.Month = pd.to_datetime(promo.Month, format='%Y-%m')

promo = promo.set_index('Month')
promo

# %%
promo_train = promo[:train_len]
promo_test = promo[train_len:]

# %%
model = SARIMAX(train_data_boxcox, order=(1,1,1), seasonal_order=(1,1,1,12), exog=promo_train)
model_fit = model.fit()

print(model_fit.params)

# %% [markdown]
# <a id="section-six_ten_one"></a>
# ### Recover Original Time Series Forecast

# %%
y_hat_sarimax = data_boxcox_diff.copy()
y_hat_sarimax['sarimax_forecast_boxcox'] = model_fit.predict(test.index.min(), test.index.max(), exog=promo_test)
y_hat_sarimax['sarimax_forecast'] = np.exp(y_hat_sarimax['sarimax_forecast_boxcox'])

# %% [markdown]
# <a id="section-six_ten_two"></a>
# ### Plot Train, Test and Forecast

# %%
plot_method(y_hat_sarimax.sarimax_forecast[test.index.min():], 'Seasonal Auto Regressive Integrated Moving Average with Exogeneous variable')

# %% [markdown]
# <a id="section-six_ten_three"></a>
# ### Calculate RMSE and MAPE to Evaluate Forecast

# %%
results = calculate_error(y_hat_sarimax.sarimax_forecast[test.index.min():], 'Seasonal Auto Regressive Integrated Moving Average with Exogeneous variable', results, 0)
results

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:150%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;color:white;">Thank You</p>
# </div>
